# %%
import pyautogui
print(
    pyautogui.position()
)
# Out:
# Point(x=1124, y=432)

# %%
# def desktop():
#     import keyboard
#     while keyboard.is_pressed('ctrl') or keyboard.is_pressed('shift'):
#         pass
#     pyautogui.hotkey('win','d')

# topRCoords = (75, 60)

# def topR():
#     pyautogui.moveTo(
#         *topRCoords
#     )
    
# def stopExec(*args):
#     raise Exception(*args)

    
# def downFromTopR(x: int):
#     if x >= 8: stopExec()
#     import time
#     ep(0.5)
#     pyautogui.moveTo(
#         topRCoords[0],
#         topRCoords[1] + 200 * x
#     )

# def rightFromTopR(x: int):
#     if x >= 19: stopExec()
#     import time
#     time.sleep(0.5)
#     pyautogui.moveTo(
#         topRCoords[0] + 150 * x,
#         topRCoords[1]
#     )
        

# def code():
#     pyautogui.hotkey('win', '3')

# %%
from Session import Session
with Session(debug=True) as s:
    print(s.iconAtPos((5,0)))
# Out:
# Position: (75, 1060)
# Element found: Comet
# Control type: ListItem
# Is enabled: True
# Is visible: True
# Comet

# %%
import time
from Session import Session
with Session() as s:
    for i in range(20):
        time.sleep(0.5)
        s.moveAtoB((0,0), (7,18))
        s.moveAtoB((7,18), (0,0))

# %%
from Game import TheSnakeGame
with TheSnakeGame(debug=True) as g:
    grid = g.getRawGrid()
    for row in grid:
        print(row)

# %%
# %reload_ext autoreload
# %autoreload 2
from Game import TheSnakeGame
with TheSnakeGame(debug=True) as g:
    g.persistSession()
# Out:
# Initial grid captured.
# Snake head found at (5, 6)
# Apple found at (1, 5): Comet
# Apple found at (1, 6): Visual Studio Code
# Apple found at (2, 5): Microsoft Edge
# Apple found at (2, 6): Zoom Workplace
# Apple found at (3, 5): McAfee
# Apple found at (3, 6): Firefox
# Apple found at (4, 6): Google Chrome
# Apples found at: {(1, 5), (4, 6), (2, 6), (3, 6), (1, 6), (2, 5), (3, 5)}
# Key pressed: 'a'
# Key recognized, performing action
# Moving snake, no apple at (5, 5)
# Key pressed: 'a'
# Key recognized, performing action
# Moving snake, no apple at (5, 4)
# Key pressed: 'w'
# Key recognized, performing action
# Moving snake, no apple at (4, 4)
# Key pressed: 'w'
# Key recognized, performing action
# Moving snake, no apple at (3, 4)
# Key pressed: 'd'
# Key recognized, performing action
# Moving snake, apple found at (3, 5)
# Key pressed: 'w'
# Key recognized, performing action
# Moving snake, apple found at (2, 5)
# Key pressed: 'w'
# Key recognized, performing action
# ...
